# %% [markdown]
# ### 1. Named Entity Recognition (NER)
# Identifies entities in text, such as names, dates, locations, and organizations.

# %%
# different spacy and en_core_web_sm versions may lead to different results
# this notebook is made with spaCy version 3.8.3 and en_core_web_sm version 3.8.0
# find your own version in the terminal: python -m spacy info
import spacy 
from spacy import displacy

NER = spacy.load("en_core_web_sm")  # Load SpaCy's small English model
sentence = "This course is lectured by Dr. S. Supraja, and Simon Liu at NTU, Singapore."

doc = NER(sentence)
for entity in doc.ents:
    print(f"{entity.text}[{entity.label_}]")
# Out:
# S. Supraja[PERSON]
# Simon Liu[PERSON]
# NTU[ORG]
# Singapore[GPE]

# %%
# use the following command to explore the definition of the given POS tag, dependency label or entity type in spacy
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This course is lectured by Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     S. Supraja
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Simon Liu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NTU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %% [markdown]
# ### 2. Part-of-Speech (POS) Tagging
# Assigning grammatical categories (like noun, verb, adjective, etc.) to words in a sentence.

# %%
# Process the text for coarse-grained POS tagging
for token in doc:
    print(f"{token.text}[{token.pos_}]")
# Out:
# This[DET]
# course[NOUN]
# is[AUX]
# lectured[VERB]
# by[ADP]
# Dr.[PROPN]
# S.[PROPN]
# Supraja[PROPN]
# ,[PUNCT]
# and[CCONJ]
# Simon[PROPN]
# Liu[PROPN]
# at[ADP]
# NTU[PROPN]
# ,[PUNCT]
# Singapore[PROPN]
# .[PUNCT]

# %%
# Process the text for fine-grained POS tagging
for token in doc:
    print(f"{token.text}[{token.tag_}]")
# Out:
# This[DT]
# course[NN]
# is[VBZ]
# lectured[VBN]
# by[IN]
# Dr.[NNP]
# S.[NNP]
# Supraja[NNP]
# ,[,]
# and[CC]
# Simon[NNP]
# Liu[NNP]
# at[IN]
# NTU[NNP]
# ,[,]
# Singapore[NNP]
# .[.]

# %%
from nltk import Tree

def tok_format(tok, coarse=False):
    if coarse:
        return "[".join([tok.orth_, tok.pos_]) + "]"
    return "[".join([tok.orth_, tok.tag_]) + "]"

def to_nltk_tree(node, coarse=False):
    if node.n_lefts + node.n_rights > 0:
        return Tree(tok_format(node), [to_nltk_tree(child, coarse=coarse) for child in node.children])
    else:
        return tok_format(node, coarse=coarse)

[to_nltk_tree(sent.root, coarse=True).pretty_print() for sent in doc.sents];
[to_nltk_tree(sent.root).pretty_print() for sent in doc.sents];
# Out:
#                                      lectured[VBN]
#     _______________________________________|_________________________________________________________
#    |       |         |         |           |                       |                              Liu[NNP]
#    |       |         |         |           |                       |                       __________|________
#    |       |         |         |           |                     by[IN]                   |                 at[IN]
#    |       |         |         |           |                       |                      |                   |
#    |       |         |         |       course[NN]             Supraja[NNP]                |                NTU[NNP]
#    |       |         |         |           |            ___________|___________           |           ________|____________
# is[AUX] ,[PUNCT] and[CCONJ] .[PUNCT]   This[DET]   Dr.[PROPN]              S.[PROPN] Simon[PROPN] ,[PUNCT]          Singapore[PROPN]
#
#                           lectured[VBN]
#     ____________________________|___________________________________________________
#    |     |      |     |         |                     |                          Liu[NNP]
#    |     |      |     |         |                     |                    _________|________
#    |     |      |     |         |                   by[IN]                |                at[IN]
#    |     |      |     |         |                     |                   |                  |
#    |     |      |     |     course[NN]           Supraja[NNP]             |               NTU[NNP]
#    |     |      |     |         |           __________|__________         |          ________|___________
# is[VBZ] ,[,] and[CC] .[.]    This[DT]   Dr.[NNP]              S.[NNP] Simon[NNP]   ,[,]            Singapore[NNP]

# %% [markdown]
# ### 3. Dependency Parsing
# Analyzing the grammatical structure of a sentence to establish relationships between words.

# %%
# Process the text for dependency parsing
print('{:<15} | {:<10} | {:<15} | {:<20}'.format('Token','Relation','Head','Children'))
print('-'*70)
for token in doc:
    #Print the token, dependency nature, head and all dependents of the token
    print("{:<15} | {:<10} | {:<15} | {:<20}"
          .format(str(token.text), str(token.dep_), str(token.head.text), str([child for child in token.children])))
# Out:
# Token           | Relation   | Head            | Children
# ----------------------------------------------------------------------
# This            | det        | course          | []
# course          | nsubjpass  | lectured        | [This]
# is              | auxpass    | lectured        | []
# lectured        | ROOT       | lectured        | [course, is, by, ,, and, Liu, .]
# by              | agent      | lectured        | [Supraja]
# Dr.             | compound   | Supraja         | []
# S.              | compound   | Supraja         | []
# Supraja         | pobj       | by              | [Dr., S.]
# ,               | punct      | lectured        | []
# and             | cc         | lectured        | []
# Simon           | compound   | Liu             | []
# Liu             | conj       | lectured        | [Simon, at]
# at              | prep       | Liu             | [NTU]
# NTU             | pobj       | at              | [,, Singapore]
# ,               | punct      | NTU             | []
# Singapore       | npadvmod   | NTU             | []
# .               | punct      | lectured        | []

# %%
# use displacy to render the text
displacy.render(doc, style='dep', jupyter=True, options={'distance':120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7329d9608085472ba3ec79aeb21c921f-0" class="displacy" width="1730" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">course</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">lectured</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Dr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">S.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Supraja,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Simon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Liu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">NTU,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Singapore.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-0" stroke-width="2px" d="M70,302.0 C70,242.0 150.0,242.0 150.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7329d9608085472ba3ec79aeb21c921f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-1" stroke-width="2px" d="M190,302.0 C190,182.0 395.0,182.0 395.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7329d9608085472ba3ec79aeb21c921f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,304.0 L182,292.0 198,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-2" stroke-width="2px" d="M310,302.0 C310,242.0 390.0,242.0 390.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7329d9608085472ba3ec79aeb21c921f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,304.0 L302,292.0 318,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-3" stroke-width="2px" d="M430,302.0 C430,242.0 510.0,242.0 510.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7329d9608085472ba3ec79aeb21c921f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">agent</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510.0,304.0 L518.0,292.0 502.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-4" stroke-width="2px" d="M670,302.0 C670,182.0 875.0,182.0 875.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7329d9608085472ba3ec79aeb21c921f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,304.0 L662,292.0 678,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-5" stroke-width="2px" d="M790,302.0 C790,242.0 870.0,242.0 870.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7329d9608085472ba3ec79aeb21c921f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,304.0 L782,292.0 798,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-6" stroke-width="2px" d="M550,302.0 C550,122.0 880.0,122.0 880.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7329d9608085472ba3ec79aeb21c921f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M880.0,304.0 L888.0,292.0 872.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7329d9608085472ba3ec79aeb21c921f-0-7" stroke-width="2px"

# %% [markdown]
# ### Practice for the week
# Perform NER, POS tagging and dependency parser on the following text and observe the results. Refer to https://spacy.io/api for more information.

# %%
import pandas as pd
import spacy

raw_text1 = "From 1925 to 1945, Tolkien was the Rawlinson and Bosworth Professor of Anglo-Saxon and a Fellow of Pembroke College, both at the University of Oxford. He then moved within the same university to become the Merton Professor of English Language and Literature and Fellow of Merton College, and held these positions from 1945 until his retirement in 1959. Tolkien was a close friend of C. S. Lewis, a co-member of the informal literary discussion group The Inklings. He was appointed a Commander of the Order of the British Empire by Queen Elizabeth II on 28 March 1972."

raw_text2 = '''
From 1925 to 1945, Tolkien was the Rawlinson and Bosworth Professor of Anglo-Saxon and a Fellow of Pembroke College, both at the University of Oxford. 
He then moved within the same university to become the Merton Professor of English Language and Literature and Fellow of Merton College, and held these positions from 1945 until his retirement in 1959. 
Tolkien was a close friend of C. S. Lewis, a co-member of the informal literary discussion group The Inklings. 
He was appointed a Commander of the Order of the British Empire by Queen Elizabeth II on 28 March 1972.
'''

df = pd.DataFrame([raw_text1, raw_text2], columns=['text'])
print(df)
# Out:
#                                                 text
# 0  From 1925 to 1945, Tolkien was the Rawlinson a...
# 1  \nFrom 1925 to 1945, Tolkien was the Rawlinson...

# %%
# load the small English Model
nlp = spacy.load('en_core_web_sm')

# lists to store tokens and tags
token = []
pos = []

# TODO: continue the codes from here
for i, doc in enumerate(nlp.pipe(df['text']), start=1):
    print(f"\n=== DOC {i} : NER ===")
    for ent in doc.ents:
        print(f"{ent.text} [{ent.label_}]")
# Out:
# === DOC 1 : NER ===
# 1925 to 1945 [DATE]
# Tolkien [PERSON]
# Anglo-Saxon [ORG]
# the University of Oxford [ORG]
# English Language and Literature and Fellow of Merton College [WORK_OF_ART]
# 1945 [DATE]
# 1959 [DATE]
# Tolkien [PERSON]
# C. S. Lewis [PERSON]
# Inklings [ORG]
# the British Empire [GPE]
# Elizabeth II [PERSON]
# 28 March 1972 [DATE]
#
# === DOC 2 : NER ===
# 1925 to 1945 [DATE]
# Tolkien [PERSON]
# Anglo-Saxon [ORG]
# the University of Oxford [ORG]
# English Language and Literature and Fellow of Merton College [WORK_OF_ART]
# 1945 [DATE]
# 1959 [DATE]
# Tolkien [PERSON]
# C. S. Lewis [PERSON]
# Inklings [ORG]
# the British Empire [GPE]
# Elizabeth II [PERSON]
# 28 March 1972 [DATE]

# %%
# Build spaCy docs for both rows in your DataFrame
docs = list(nlp.pipe(df['text']))

def fmt(sent, use="pos"):
    # use="pos" for coarse (tok.pos_), use="tag" for fine (tok.tag_)
    if use == "tag":
        return "".join(f"{t.text}[{t.tag_}]{t.whitespace_}" for t in sent).strip()
    return "".join(f"{t.text}[{t.pos_}]{t.whitespace_}" for t in sent).strip()

for doc_i, doc in enumerate(docs, start=1):
    print(f"\n=== DOC {doc_i} — Coarse POS (pos_) ===")
    for sent_i, sent in enumerate(doc.sents, start=1):
        print(f"({sent_i}) {fmt(sent, use='pos')}")

    print(f"\n=== DOC {doc_i} — Fine POS (tag_) ===")
    for sent_i, sent in enumerate(doc.sents, start=1):
        print(f"({sent_i}) {fmt(sent, use='tag')}")
# Out:
# === DOC 1 — Coarse POS (pos_) ===
# (1) From[ADP] 1925[NUM] to[ADP] 1945[NUM],[PUNCT] Tolkien[PROPN] was[AUX] the[DET] Rawlinson[PROPN] and[CCONJ] Bosworth[PROPN] Professor[PROPN] of[ADP] Anglo[PROPN]-[PUNCT]Saxon[PROPN] and[CCONJ] a[DET] Fellow[PROPN] of[ADP] Pembroke[PROPN] College[PROPN],[PUNCT] both[PRON] at[ADP] the[DET] University[PROPN] of[ADP] Oxford[PROPN].[PUNCT]
# (2) He[PRON] then[ADV] moved[VERB] within[ADP] the[DET] same[ADJ] university[NOUN] to[PART] become[VERB] the[DET] Merton[PROPN] Professor[PROPN] of[ADP] English[PROPN] Language[PROPN] and[CCONJ] Literature[PROPN] and[CCONJ] Fellow[PROPN] of[ADP] Merton[PROPN] College[PROPN],[PUNCT] and[CCONJ] held[VERB] these[DET] positions[NOUN] from[ADP] 1945[NUM] until[ADP] his[PRON] retirement[NOUN] in[ADP] 1959[NUM].[PUNCT]
# (3) Tolkien[PROPN] was[AUX] a[DET] close[ADJ] friend[NOUN] of[ADP] C.[PROPN] S.[PROPN] Lewis[PROPN],[PUNCT] a[DET] co[NOUN]-[NOUN]member[NOUN] of[ADP] the[DET] informal[ADJ] literary[ADJ] discussion[NOUN] group[NOUN] The[PROPN] Inklings[PROPN].[PUNCT]
# (4) He[PRON] was[AUX] appointed[VERB] a[DET] Commander[PROPN] of[ADP] the[DET] Order[PROPN] of[ADP] the[DET] British[PROPN] Empire[PROPN] by[ADP] Queen[PROPN] Elizabeth[PROPN] II[PROPN] on[ADP] 28[NUM] March[PROPN] 1972[NUM].[PUNCT]
#
# === DOC 1 — Fine POS (tag_) ===
# (1) From[IN] 1925[CD] to[IN] 1945[CD],[,] Tolkien[NNP] was[VBD] the[DT] Rawlinson[NNP] and[CC] Bosworth[NNP] Professor[NNP] of[IN] Anglo[NNP]-[HYPH]Saxon[NNP] and[CC] a[DT] Fellow[NNP] of[IN] Pembroke[NNP] College[NNP],[,] both[DT] at[IN] the[DT] University[NNP] of[IN] Oxford[NNP].[.]
# (2) He[PRP] then[RB] moved[VBD] within[IN] the[DT] same[JJ] university[NN] to[TO] become[VB] the[DT] Merton[NNP] Professor[NNP] of[IN] English[NNP] Language[NNP] and[CC] Literature[NNP] and[CC] Fellow[NNP] of[IN] Merton[NNP] College[NNP],[,] and[CC] held[VBD] these[DT] positions[NNS] from[IN] 1945[CD] until[IN] his[PRP$] retirement[NN] in[IN] 1959[CD].[.]
# (3) Tolkien[NNP] was[VBD] a[DT] close[JJ] friend[NN] of[IN] C.[NNP] S.[NNP] Lewis[NNP],[,] a[DT] co[NN]-[NN]member[NN] of[IN] the[DT] informal[JJ] literary[JJ] discussion[NN] group[NN] The[NNP] Inklings[NNP].[.]
# (4) He[PRP] was[VBD] appointed[VBN] a[DT] Commander[NNP] of[IN] the[DT] Order[NNP] of[IN] the[DT] British[NNP] Empire[NNP] by[IN] Queen[NNP] Elizabeth[NNP] II[NNP] on[IN] 28[CD] March[NNP] 1972[CD].[.]
#
# === DOC 2 — Coarse POS (pos_) ===
# (1) [SPACE]From[ADP] 1925[NUM] to[ADP] 1945[NUM],[PUNCT] Tolkien[PROPN] was[AUX] the[DET] Rawlinson[PROPN] and[CCONJ] Bosworth[PROPN] Professor[PROPN] of[ADP] Anglo[PROPN]-[PUNCT]Saxon[PROPN] and[CCONJ] a[DET] Fellow[PROPN] of[ADP] Pembroke[PROPN] College[PROPN],[PUNCT] both[PRON] at[ADP] the[DET] University[PROPN] of[ADP] Oxford[PROPN].[PUNCT]
# [SPACE]
# (2) He[PRON] then[ADV] moved[VERB] within[ADP] the[DET] same[ADJ] university[NOUN] to[PART] become[VERB] the[DET] Merton[PROPN] Professor[PROPN] of[ADP] English[PROPN] Language[PROPN] and[CCONJ] Literature[PROPN] and[CCONJ] Fellow[PROPN] of[ADP] Merton[PROPN] College[PROPN],[PUNCT] and[CCONJ] held[VERB] these[DET] positions[NOUN] from[ADP] 1945[NUM] until[ADP] his[PRON] retirement[NOUN] in[ADP] 1959[NUM].[PUNCT]
# [SPACE]
# (3) Tolkien[PROPN] was[AUX] a[DET] close[ADJ] friend[NOUN] of[ADP] C.[PROPN] S.[PROPN] Lewis[PROPN],[PUNCT] a[DET] co[NOUN]-[NOUN]member[NOUN] of[ADP] the[DET] informal[ADJ] literary[ADJ] discussion[NOUN] group[NOUN] The[PROPN] Inklings[PROPN].[PUNCT]
# [SPACE]
# (4) He[PRON] was[AUX] appointed[VERB] a[DET] Commander[PROPN] of[ADP] the[DET] Order[PROPN] of[ADP] the[DET] British[PROPN] Empire[PROPN] by[ADP] Queen[PROPN] Elizabeth[PROPN] II[PROPN] on[ADP] 28[NUM] March[PROPN] 1972[NUM].[PUNCT]
# [SPACE]
#
# === DOC 2 — Fine POS (tag_) ===
# (1) [_SP]From[IN] 1925[CD] to[IN] 1945[CD],[,] Tolkien[NNP] was[VBD] the[DT] Rawlinson[NNP] and[CC] Bosworth[NNP] Professor[NNP] of[IN] Anglo[NNP]-[HYPH]Saxon[NNP] and[CC] a[DT] Fellow[NNP] of[IN] Pembroke[NNP] College[NNP],[,] both[DT] at[IN] the[DT] University[NNP] of[IN] Oxford[NNP].[.]
# [_SP]
# (2) He[PRP] then[RB] moved[VBD] within[IN] the[DT] same[JJ] university[NN] to[TO] become[VB] the[DT] Merton[NNP] Professor[NNP] of[IN] English[NNP] Language[NNP] and[CC] Literature[NNP] and[CC] Fellow[NNP] of[IN] Merton[NNP] College[NNP],[,] and[CC] held[VBD] these[DT] positions[NNS] from[IN] 1945[CD] until[IN] his[PRP$] retirement[NN] in[IN] 1959[CD].[.]
# [_SP]
# (3) Tolkien[NNP] was[VBD] a[DT] close[JJ] friend[NN] of[IN] C.[NNP] S.[NNP] Lewis[NNP],[,] a[DT] co[NN]-[NN]member[NN] of[IN] the[DT] informal[JJ] literary[JJ] discussion[NN] group[NN] The[NNP] Inklings[NNP].[.]
# [_SP]
# (4) He[PRP] was[VBD] appointed[VBN] a[DT] Commander[NNP] of[IN] the[DT] Order[NNP] of[IN] the[DT] British[NNP] Empire[NNP] by[IN] Queen[NNP] Elizabeth[NNP] II[NNP] on[IN] 28[CD] March[NNP] 1972[CD].[.]
# [_SP]

# %%
from nltk import Tree

def tok_format(tok, mode="fine"):
    """
    mode:
      - "coarse" -> token[POS]
      - "fine"   -> token[TAG]
      - "dep"    -> token[DEP:POS]
    """
    if mode == "coarse":
        tag = tok.pos_
    elif mode == "dep":
        tag = f"{tok.dep_}:{tok.pos_}"
    else:  # "fine"
        tag = tok.tag_
    return f"{tok.text}[{tag}]"

def to_nltk_tree(node, mode="fine"):
    """Convert a spaCy token subtree rooted at `node` into an NLTK Tree."""
    if node.n_lefts + node.n_rights > 0:
        return Tree(
            tok_format(node, mode),
            [to_nltk_tree(child, mode=mode) for child in node.children]
        )
    else:
        return tok_format(node, mode)

# Build one tree per sentence for different labeling modes
coarse_trees = [to_nltk_tree(sent.root, mode="coarse") for sent in doc.sents]
fine_trees   = [to_nltk_tree(sent.root, mode="fine")   for sent in doc.sents]
dep_trees    = [to_nltk_tree(sent.root, mode="dep")    for sent in doc.sents]

# Pretty print (coarse POS)
for i, t in enumerate(coarse_trees, 1):
    print(f"\nSentence {i} — coarse POS:")
    t.pretty_print()

# If you also want the others, uncomment:
# for i, t in enumerate(fine_trees, 1):
#     print(f"\nSentence {i} — fine POS (PTB tag):")
#     t.pretty_print()
#
# for i, t in enumerate(dep_trees, 1):
#     print(f"\nSentence {i} — dependency label + POS:")
#     t.pretty_print()
# Out:
# Sentence 1 — coarse POS:
#                                                                                      was[AUX]
#     ____________________________________________________________________________________|____________________________________________________________________________________________________________________________________________________________
#    |           |                    |                                                                             Professor[PROPN]                                                                                                                   |
#    |           |                    |                    ________________________________________________________________|__________________________________________________________________________________                                         |
#    |           |                    |                   |         |                     |                                               |                       Fellow[PROPN]                            at[ADP]                                     |
#    |           |                    |                   |         |                     |                                               |                   __________|______________              _________|_____________                           |
#    |           |                From[ADP]               |         |                     |                                            of[ADP]               |                      of[ADP]         |               University[PROPN]                  |
#    |           |            ________|_________          |         |                     |                                               |                  |                         |            |          _____________|_______________           |
#    |           |           |        |      to[ADP]      |         |              Rawlinson[PROPN]                                  Saxon[PROPN]            |                   College[PROPN]     |         |                          of[ADP]    .[PUNCT]
#    |           |           |        |         |         |         |         ____________|________________                 ______________|__________        |                         |            |         |                             |          |
# ,[PUNCT] Tolkien[PROPN]         1925[NUM] 1945[NUM] and[CCONJ] ,[PUNCT] the[DET]    and[CCONJ]    Bosworth[PROPN]   Anglo[PROPN]                -[PUNCT] a[DET]               Pembroke[PROPN] both[PRON] the[DET]                   Oxford[PROPN]
#                         [SPACE]                                                                                                                                                                                                                   [SPACE]
#
#
# Sentence 2 — coarse POS:
#                                                                                                             moved[VERB]
#     _____________________________________________________________________________________________________________|______________________________________________________________________________________________________________________________________________________
#    |         |        |         |                      |                                                    become[VERB]                                                                                                 |                                              |
#    |         |        |         |                      |                       __________________________________|_______________                                                                                        |                                              |
#    |         |        |         |                      |                      |                                           Professor[PROPN]                                                                           held[VERB]                                         |
#    |         |        |         |                      |                      |         _________________________________________|__________________________________________________________                 ____________|_______________________                       |
#    |         |        |         |                      |                      |        |           |                          of[ADP]                                                       |               |            |                   until[ADP]                 |
#    |         |        |         |                      |                      |        |           |                             |                                                          |               |            |                       |                      |
#    |         |        |         |                 within[ADP]                 |        |           |                      Language[PROPN]                                                of[ADP]            |            |                retirement[NOUN]              |
#    |         |        |         |                      |                      |        |           |              _______________|____________________________                              |               |            |           ____________|_____________         |
#    |         |        |         |               university[NOUN]              |        |           |             |               |                    Literature[PROPN]               College[PROPN] positions[NOUN] from[ADP]      |                       in[ADP]  .[PUNCT]
#    |         |        |         |          ____________|_____________         |        |           |             |               |              ______________|_______________              |               |            |          |                          |        |
# He[PRON] then[ADV] ,[PUNCT] and[CCONJ] the[DET]                  same[ADJ] to[PART] the[DET] Merton[PROPN] English[PROPN]    and[CCONJ]    and[CCONJ]                   Fellow[PROPN] Merton[PROPN]     these[DET]   1945[NUM]  his[PRON]                  1959[NUM]
#                                                                                                                                                                                                                                                                      [SPACE]
#
#
# Sentence 3 — coarse POS:
#                                                                 was[AUX]
#        ____________________________________________________________|_____________________________________________________________________________________________
#       |                                                       friend[NOUN]                                                                                       |
#       |           _________________________________________________|____________                                                                                 |
#       |          |        |                                                  of[ADP]                                                                             |
#       |          |        |                                                     |                                                                                |
#       |          |        |                                                Lewis[PROPN]                                                                          |
#       |          |        |           __________________________________________|____________________________________                                            |
#       |          |        |          |         |        |          |            |                               member[NOUN]                                     |
#       |          |        |          |         |        |          |            |                                    |                                           |
#       |          |        |          |         |        |          |            |                                 of[ADP]                                        |
#       |          |        |          |         |        |          |            |                                    |                                           |
#       |          |        |          |         |        |          |            |                               group[NOUN]                                      |
#       |          |        |          |         |        |          |            |           _________________________|_______________________________            |
#       |          |        |          |         |        |          |         co[NOUN]      |           |             |              |         Inklings[PROPN] .[PUNCT]
#       |          |        |          |         |        |          |            |          |           |             |              |                |           |
# Tolkien[PROPN] a[DET] close[ADJ] C.[PROPN] S.[PROPN] ,[PUNCT]   -[NOUN]       a[DET]    the[DET] informal[ADJ] literary[ADJ] discussion[NOUN]    The[PROPN]
#                                                                                                                                                               [SPACE]
#
#
# Sentence 4 — coarse POS:
#                                                        appointed[VERB]
#     __________________________________________________________|__________________________________________________________________________________
#    |        |            Commander[PROPN]                                                                                   |                    |
#    |        |        ___________|______________                                                                             |                    |
#    |        |       |                       of[ADP]                                                                         |                    |
#    |        |       |                          |                                                                            |                    |
#    |        |       |                     Order[PROPN]                                                                      |                    |
#    |        |       |            ______________|______________                                                              |                    |
#    |        |       |           |                          of[ADP]                                                          |                    |
#    |        |       |           |                             |                                                             |                    |
#    |        |       |           |                       Empire[PROPN]                                                       |                    |
#    |        |       |           |               ______________|_________________________                                    |                    |
#    |        |       |           |              |              |                      by[ADP]                             on[ADP]                 |
#    |        |       |           |              |              |                         |                                   |                    |
#    |        |       |           |              |              |                     II[PROPN]                          March[PROPN]           .[PUNCT]
#    |        |       |           |              |              |              ___________|____________              _________|___________         |
# He[PRON] was[AUX] a[DET]     the[DET]       the[DET]    British[PROPN] Queen[PROPN]           Elizabeth[PROPN] 28[NUM]              1972[NUM]
#                                                                                                                                               [SPACE]

# %%
from spacy import displacy

# Build spaCy docs for both rows in your DataFrame
docs = list(nlp.pipe(df['text']))

for doc_i, doc in enumerate(docs, start=1):
    for sent_i, sent in enumerate(doc.sents, start=1):
        print(f"\n=== DOC {doc_i} • Sentence {sent_i} ===")
        print('{:<15} | {:<10} | {:<15} | {}'.format('Token','Relation','Head','Children'))
        print('-'*90)
        for token in sent:
            children = ", ".join(child.text for child in token.children) or "-"
            print("{:<15} | {:<10} | {:<15} | {}"
                  .format(token.text, token.dep_, token.head.text, children))

        # Render the dependency parse for this sentence (Jupyter-friendly)
        displacy.render(sent, style='dep', jupyter=True, options={'distance': 120})
# Out:
# === DOC 1 • Sentence 1 ===
# Token           | Relation   | Head            | Children
# ------------------------------------------------------------------------------------------
# From            | prep       | was             | 1925, to
# 1925            | pobj       | From            | -
# to              | prep       | From            | 1945
# 1945            | pobj       | to              | -
# ,               | punct      | was             | -
# Tolkien         | nsubj      | was             | -
# was             | ROOT       | was             | From, ,, Tolkien, Professor, .
# the             | det        | Rawlinson       | -
# Rawlinson       | nmod       | Professor       | the, and, Bosworth
# and             | cc         | Rawlinson       | -
# Bosworth        | conj       | Rawlinson       | -
# Professor       | attr       | was             | Rawlinson, of, and, Fellow, ,, at
# of              | prep       | Professor       | Saxon
# Anglo           | compound   | Saxon           | -
# -               | punct      | Saxon           | -
# Saxon           | pobj       | of              | Anglo, -
# and             | cc         | Professor       | -
# a               | det        | Fellow          | -
# Fellow          | conj       | Professor       | a, of
# of              | prep       | Fellow          | College
# Pembroke        | compound   | College         | -
# College         | pobj       | of              | Pembroke
# ,               | punct      | Professor       | -
# both            | preconj    | at              | -
# at              | prep       | Professor       | both, University
# the             | det        | University      | -
# University      | pobj       | at              | the, of
# of              | prep       | University      | Oxford
# Oxford          | pobj       | of              | -
# .               | punct      | was             | -
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="854653e10ab54de1b98b9a2de564e287-0" class="displacy" width="3170" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">From</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">1925</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">1945,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Tolkien</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Rawlinson</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Bosworth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Professor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">Anglo-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Saxon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Fellow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Pembroke</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">College,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">University</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Oxford.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-854653e10ab54de1b98b9a2de564e287-0-0" stroke-width="2px" d="M70,302.0 C70,122.0 640.0,122.0 640.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-854653e10ab54de1b98b9a2de564e287-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-854653e10ab54de1b98b9a2de564e287-0-1" stroke-width="2px" d="M70,302.0 C70,242.0 150.0,242.0 150.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-854653e10ab54de1b98b9a2de564e287-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150.0,304.0 L158.0,292.0 142.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displa
# === DOC 1 • Sentence 2 ===
# Token           | Relation   | Head            | Children
# ------------------------------------------------------------------------------------------
# He              | nsubj      | moved           | -
# then            | advmod     | moved           | -
# moved           | ROOT       | moved           | He, then, within, become, ,, and, held, .
# within          | prep       | moved           | university
# the             | det        | university      | -
# same            | amod       | university      | -
# university      | pobj       | within          | the, same
# to              | aux        | become          | -
# become          | advcl      | moved           | to, Professor
# the             | det        | Professor       | -
# Merton          | compound   | Professor       | -
# Professor       | attr       | become          | the, Merton, of, of
# of              | prep       | Professor       | Language
# English         | compound   | Language        | -
# Language        | pobj       | of              | English, and, Literature
# and             | cc         | Language        | -
# Literature      | conj       | Language        | and, Fellow
# and             | cc         | Literature      | -
# Fellow          | conj       | Literature      | -
# of              | prep       | Professor       | College
# Merton          | compound   | College         | -
# College         | pobj       | of              | Merton
# ,               | punct      | moved           | -
# and             | cc         | moved           | -
# held            | conj       | moved           | positions, from, until
# these           | det        | positions       | -
# positions       | dobj       | held            | these
# from            | prep       | held            | 1945
# 1945            | pobj       | from            | -
# until           | prep       | held            | retirement
# his             | poss       | retirement      | -
# retirement      | pobj       | until           | his, in
# in              | prep       | retirement      | 1959
# 1959            | pobj       | in              | -
# .               | punct      | moved           | -
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f316e0f4a467498a9dab9d224e5d935b-0" class="displacy" width="4010" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">then</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">moved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">within</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">same</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">university</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">become</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Merton</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Professor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">English</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">Literature</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">Fellow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">Merton</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">College,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">held</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">these</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">positions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">1945</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">until</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">retirement</tspan>
#     <tspan class="displacy-tag" dy="2em" f
# === DOC 1 • Sentence 3 ===
# Token           | Relation   | Head            | Children
# ------------------------------------------------------------------------------------------
# Tolkien         | nsubj      | was             | -
# was             | ROOT       | was             | Tolkien, friend, .
# a               | det        | friend          | -
# close           | amod       | friend          | -
# friend          | attr       | was             | a, close, of
# of              | prep       | friend          | Lewis
# C.              | compound   | Lewis           | -
# S.              | compound   | Lewis           | -
# Lewis           | pobj       | of              | C., S., ,, co, -, member
# ,               | punct      | Lewis           | -
# a               | det        | co              | -
# co              | appos      | Lewis           | a
# -               | appos      | Lewis           | -
# member          | appos      | Lewis           | of
# of              | prep       | member          | group
# the             | det        | group           | -
# informal        | amod       | group           | -
# literary        | amod       | group           | -
# discussion      | compound   | group           | -
# group           | pobj       | of              | the, informal, literary, discussion, Inklings
# The             | compound   | Inklings        | -
# Inklings        | appos      | group           | The
# .               | punct      | was             | -
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8c5f9e1ab6a04d6fb862df017b9cba8d-0" class="displacy" width="2450" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Tolkien</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">close</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">friend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">C.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">S.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Lewis,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">co-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">member</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">informal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">literary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">discussion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">group</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">Inklings.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-0" stroke-width="2px" d="M70,302.0 C70,242.0 150.0,242.0 150.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-1" stroke-width="2px" d="M310,302.0 C310,182.0 515.0,182.0 515.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,304.0 L302,292.0 318,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-2" stroke-width="2px" d="M430,302.0 C430,242.0 510.0,242.0 510.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,304.0 L422,292.0 438,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-3" stroke-width="2px" d="M190,302.0 C190,122.0 520.0,122.0 520.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520.0,304.0 L528.0,292.0 512.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-4" stroke-width="2px" d="M550,302.0 C550,242.0 630.0,242.0 630.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8c5f9e1ab6a04d6fb862df017b9cba8d-0-4" class="displacy-label" startOffset="50%
# === DOC 1 • Sentence 4 ===
# Token           | Relation   | Head            | Children
# ------------------------------------------------------------------------------------------
# He              | nsubjpass  | appointed       | -
# was             | auxpass    | appointed       | -
# appointed       | ROOT       | appointed       | He, was, Commander, on, .
# a               | det        | Commander       | -
# Commander       | oprd       | appointed       | a, of
# of              | prep       | Commander       | Order
# the             | det        | Order           | -
# Order           | pobj       | of              | the, of
# of              | prep       | Order           | Empire
# the             | det        | Empire          | -
# British         | compound   | Empire          | -
# Empire          | pobj       | of              | the, British, by
# by              | prep       | Empire          | II
# Queen           | compound   | II              | -
# Elizabeth       | compound   | II              | -
# II              | pobj       | by              | Queen, Elizabeth
# on              | prep       | appointed       | March
# 28              | nummod     | March           | -
# March           | pobj       | on              | 28, 1972
# 1972            | nummod     | March           | -
# .               | punct      | appointed       | -
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="df3c7b3a2fb7498880a24faa9ca7a74d-0" class="displacy" width="2450" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">appointed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Commander</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">British</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Empire</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Queen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Elizabeth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">II</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">28</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">March</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">1972.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-0" stroke-width="2px" d="M70,242.0 C70,122.0 280.0,122.0 280.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-1" stroke-width="2px" d="M190,242.0 C190,182.0 275.0,182.0 275.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,244.0 L182,232.0 198,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-2" stroke-width="2px" d="M430,242.0 C430,182.0 515.0,182.0 515.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-3" stroke-width="2px" d="M310,242.0 C310,122.0 520.0,122.0 520.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">oprd</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520.0,244.0 L528.0,232.0 512.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-4" stroke-width="2px" d="M550,242.0 C550,182.0 635.0,182.0 635.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-df3c7b3a2fb7498880a24faa9ca7a74d-0-4" class="displacy-label" startOffset="50%
# === DOC 2 • Sentence 1 ===
# Token           | Relation   | Head            | Children
# ------------------------------------------------------------------------------------------
#
#                | dep        | From            | -
# From            | prep       | was             |
# , 1925, to
# 1925            | pobj       | From            | -
# to              | prep       | From            | 1945
# 1945            | pobj       | to              | -
# ,               | punct      | was             | -
# Tolkien         | nsubj      | was             | -
# was             | ROOT       | was             | From, ,, Tolkien, Professor, .
# the             | det        | Rawlinson       | -
# Rawlinson       | nmod       | Professor       | the, and, Bosworth
# and             | cc         | Rawlinson       | -
# Bosworth        | conj       | Rawlinson       | -
# Professor       | attr       | was             | Rawlinson, of, and, Fellow, ,, at
# of              | prep       | Professor       | Saxon
# Anglo           | compound   | Saxon           | -
# -               | punct      | Saxon           | -
# Saxon           | pobj       | of              | Anglo, -
# and             | cc         | Professor       | -
# a               | det        | Fellow          | -
# Fellow          | conj       | Professor       | a, of
# of              | prep       | Fellow          | College
# Pembroke        | compound   | College         | -
# College         | pobj       | of              | Pembroke
# ,               | punct      | Professor       | -
# both            | preconj    | at              | -
# at              | prep       | Professor       | both, University
# the             | det        | University      | -
# University      | pobj       | at              | the, of
# of              | prep       | University      | Oxford
# Oxford          | pobj       | of              | -
# .               | punct      | was             |
#
#
#                | dep        | .               | -
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="764c132f619547839f7519072e547d2f-0" class="displacy" width="3410" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">From</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">1925</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">1945,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Tolkien</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Rawlinson</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Bosworth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Professor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Anglo-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Saxon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">Fellow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">Pembroke</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">College,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">University</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">Oxford.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">
# </tspan>
# ...
#     <tspan class="displacy-word" fill="currentColor" x="530">friend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">C.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">S.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">Lewis,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">co-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">member</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">informal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">literary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">discussion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">group</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">Inklings.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f06b3b21cccf47b192735bb94fa0de63-0-0" stroke-width="2px" d="M70,362.0 C70,302.0 145.0,302.0 145.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f06b3b21cccf47b192735bb94fa0de63-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,364.0 L62,352.0 78,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f06b3b21cccf47b192735bb94fa0de63-0-1" stroke-width="2px" d="M310,362.0 C310,242.0 510.0,242.0 510.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f06b3b21cccf47b192735bb94fa0de63-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,364.0 L302,352.0 318,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f06b3b21cccf47b192735bb94fa0de63-0-2" stroke-width="2px" d="M430,362.0 C430,302.0 505.0,302.0 505.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f06b3b21cccf47b192735bb94fa0de63-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,364.0 L422,352.0 438,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f06b3b21cccf47b192735bb94fa0de63-0-3" stroke-width="2px" d="M190,362.0 C190,182.0 515.0,182.0 515.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f06b3b21cccf47b192735bb94fa0de63-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M515.0,364.0 L523.0,352.0 507.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f06b3b21cccf47b192735bb94fa0de63-0-4" stroke-width="2px" d="M550,362.0 C550,302.
# === DOC 2 • Sentence 4 ===
# Token           | Relation   | Head            | Children
# ------------------------------------------------------------------------------------------
# He              | nsubjpass  | appointed       | -
# was             | auxpass    | appointed       | -
# appointed       | ROOT       | appointed       | He, was, Commander, on, .
# a               | det        | Commander       | -
# Commander       | oprd       | appointed       | a, of
# of              | prep       | Commander       | Order
# the             | det        | Order           | -
# Order           | pobj       | of              | the, of
# of              | prep       | Order           | Empire
# the             | det        | Empire          | -
# British         | compound   | Empire          | -
# Empire          | pobj       | of              | the, British, by
# by              | prep       | Empire          | II
# Queen           | compound   | II              | -
# Elizabeth       | compound   | II              | -
# II              | pobj       | by              | Queen, Elizabeth
# on              | prep       | appointed       | March
# 28              | nummod     | March           | -
# March           | pobj       | on              | 28, 1972
# 1972            | nummod     | March           | -
# .               | punct      | appointed       |
#
#
#                | dep        | .               | -
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5102d569d62b43878feabb420586140b-0" class="displacy" width="2570" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">appointed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Commander</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">British</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Empire</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">Queen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">Elizabeth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">II</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">28</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">March</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">1972.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5102d569d62b43878feabb420586140b-0-0" stroke-width="2px" d="M70,302.0 C70,182.0 275.0,182.0 275.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5102d569d62b43878feabb420586140b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,304.0 L62,292.0 78,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5102d569d62b43878feabb420586140b-0-1" stroke-width="2px" d="M190,302.0 C190,242.0 270.0,242.0 270.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5102d569d62b43878feabb420586140b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,304.0 L182,292.0 198,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5102d569d62b43878feabb420586140b-0-2" stroke-width="2px" d="M430,302.0 C430,242.0 510.0,242.0 510.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5102d569d62b43878feabb420586140b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,304.0 L422,292.0 438,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5102d569d62b43878feabb420586140b-0-3" stroke-width="2px" d="M310,302.0 C310,182.0 515.0,182.0 515.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5102d569d62b43878feabb420586140b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">oprd</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M515.0,304.0 L523.0,292.0 507.0,292.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5102d569d62b43878feabb420586140b-0-4" stroke-width="2px" d="M550,302.0 C550,24
